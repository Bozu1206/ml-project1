# %%
import pandas as pd
import numpy as np
import sys
sys.path.append('../src')  
from helpers import load_csv_data

# %%
x_train, x_test, y_train, train_ids, test_ids = load_csv_data("../data/raw/dataset_to_release")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/francoisdumoncel/Library/Mobile Documents/com~apple~CloudDocs/Desktop/02-EPFL/MA1/ML/ml-project1/notebooks/elisa_exploration.ipynb Cellule 2 line 1
# ----> <a href='vscode-notebook-cell:/Users/francoisdumoncel/Library/Mobile%20Documents/com~apple~CloudDocs/Desktop/02-EPFL/MA1/ML/ml-project1/notebooks/elisa_exploration.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> X_raw, y_raw = load_csv_data("../data/raw/x_train.csv","../data/raw/y_train.csv")
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Desktop/02-EPFL/MA1/ML/ml-project1/notebooks/../src/helpers.py:23, in load_csv_data(data_path, sub_sample)
#       7 def load_csv_data(data_path, sub_sample=False):
#       8     """
#       9     This function loads the data and returns the respectinve numpy arrays.
#      10     Remember to put the 3 files in the same folder and to not change the names of the files.
#    (...)
#      21         test_ids (np.array): ids of test data
#      22     """
# ---> 23     y_train = np.genfromtxt(
#      24         os.path.join(data_path, "y_train.csv"),
#      25         delimiter=",",
#      26         skip_header=1,
#      27         dtype=int,
#      28         usecols=1,
#      29     )
#      30     x_train = np.genfromtxt(
#      31         os.path.join(data_path, "x_train.csv"), delimiter=",", skip_header=1
#      32     )
#      33     x_test = np.genfromtxt(
#      34         os.path.join(data_path, "x_test.csv"), delimiter=",", skip_header=1
#      35     )
#
# File ~/anaconda3/envs/ada/lib/python3.9/site-packages/numpy/lib/npyio.py:1980, in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, ndmin, like)
#    1978     fname = os_fspath(fname)
#    1979 if isinstance(fname, str):
# -> 1980     fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1981     fid_ctx = contextlib.closing(fid)
#    1982 else:
#
# File ~/anaconda3/envs/ada/lib/python3.9/site-packages/numpy/lib/_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/anaconda3/envs/ada/lib/python3.9/site-packages/numpy/lib/_datasource.py:533, in DataSource.open(self, path, mode, encoding, newline)
#     530     return _file_openers[ext](found, mode=mode,
#     531                               encoding=encoding, newline=newline)
#     532 else:
# --> 533     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: ../data/raw/x_train.csv/y_train.csv not found.

# %%
df_X = pd.read_csv("../data/raw/dataset_to_release/x_train.csv")
df_X['_BMI5']
# Out:
# 0         20.78
# 1         28.70
# 2           NaN
# 3         27.96
# 4         24.39
#           ...
# 328130    24.69
# 328131    24.39
# 328132    58.53
# 328133    35.87
# 328134    22.81
# Name: _BMI5, Length: 328135, dtype: float64

# %%
useful_col = dict.fromkeys(df_X.columns, 'No')

# %%
# useful columns:
useful_col['GENHLTH'] = 'Yes' #same, 7, 9, BLANK to nan
useful_col['PHYSHLTH'] = 'Yes' #same, 88 to 0, 77 and 99 and BLANK to nan, poly

useful_col['MENTHLTH'] = 'Yes' #same, 88 to 0, 77 and 99 to nan, poly

useful_col['HLTHPLN1'] = 'Yes' #same, 7 and 9 to nan
useful_col['MEDCOST'] = 'Yes' #same, 7,9 BLANK to nan
useful_col['CHECKUP1'] = 'Yes' # 8 to 5, 7 and 9 and BLANK to nan

useful_col['CVDSTRK3'] = 'Yes' #same, 2 to 0,  7 and 9 to nan

useful_col['CHCSCNCR'] = 'Yes' # 7, 9 BLANK to nan

useful_col['CHCOCNCR'] = 'Yes' # 7 and 9 to nan
useful_col['CHCCOPD1'] = 'Yes' # 7 and 9 to nan

useful_col['HAVARTH3'] = 'Yes' # new, 2:0, 7 and 9 to nan

useful_col['ADDEPEV2'] = 'Yes' # 2:0, 7 and 9 to nan 

useful_col['CHCKIDNY'] = 'Yes' # new 2:0, 7 and 9 to nan 

useful_col['DIABETE3'] = 'Yes' #same, 2:0, 3:0, 1:2, 4:1, 7 and 9 to nan
useful_col['SEX'] = 'Yes' # nothing to change 

useful_col['EDUCA'] = 'Yes' # new, 9 to 1

useful_col['INCOME2'] = 'Yes' # new, 77, 99 to nan

useful_col['USEEQUIP'] = 'Yes' # new 2:0, 7,9 to nan

useful_col['DIFFWALK'] = 'Yes' # new 7,9 to nan and 2:0

useful_col['MAXDRNKS'] = 'Yes' # 77, 99 , BLANK to 0
useful_col['_RFHYPE5'] = 'Yes' #same, 1 to 0 and 2 to 1, 9 to nan
useful_col['_RFCHOL'] = 'Yes' # 1 to 0, 2 to 1, 9 and BLANK to nan
useful_col['_ASTHMS1'] = 'Yes' # 3 to 0, 2 to 1, 1 to 2, 9 to nan
useful_col['_DRDXAR1'] = 'Yes' # 2 to 0, BLANK to nan
useful_col['_RACE'] = 'Yes' # 9 to nan 
useful_col['_AGEG5YR'] = 'Yes' # 14 to nan, poly
useful_col['_BMI5'] = 'Yes' #same, BLANK to nan, divide by 100, poly
useful_col['_SMOKER3'] = 'Yes' # 9 to nan

useful_col['DROCDY3_'] = 'Yes' # new 900 to nan

useful_col['_DRNKWEK'] = 'Yes' # 99900 to nan, poly
useful_col['_FRTLT1'] = 'Yes' #same, 2 to 0, 9 to nan
useful_col['_VEGLT1'] = 'Yes' #same, 2 to 0, 9 to nan
useful_col['_TOTINDA'] = 'Yes' #same, 2 to 0, 9 to nan

useful_col['METVL11_'] = 'Yes' # new 

useful_col['MAXVO2_'] = 'Yes' # new, 99900 to nan

useful_col['FC60_'] = 'Yes' # 99900 to nan, poly

useful_col['STRFREQ_'] = 'Yes' # new, 99000 to nan

# %%
useful_col
# Out:
# {'Id': 'No',
#  '_STATE': 'No',
#  'FMONTH': 'No',
#  'IDATE': 'No',
#  'IMONTH': 'No',
#  'IDAY': 'No',
#  'IYEAR': 'No',
#  'DISPCODE': 'No',
#  'SEQNO': 'No',
#  '_PSU': 'No',
#  'CTELENUM': 'No',
#  'PVTRESD1': 'No',
#  'COLGHOUS': 'No',
#  'STATERES': 'No',
#  'CELLFON3': 'No',
#  'LADULT': 'No',
#  'NUMADULT': 'No',
#  'NUMMEN': 'No',
#  'NUMWOMEN': 'No',
#  'CTELNUM1': 'No',
#  'CELLFON2': 'No',
#  'CADULT': 'No',
#  'PVTRESD2': 'No',
#  'CCLGHOUS': 'No',
#  'CSTATE': 'No',
#  'LANDLINE': 'No',
#  'HHADULT': 'No',
#  'GENHLTH': 'Yes',
#  'PHYSHLTH': 'Yes',
#  'MENTHLTH': 'Yes',
#  'POORHLTH': 'No',
#  'HLTHPLN1': 'Yes',
#  'PERSDOC2': 'No',
#  'MEDCOST': 'Yes',
#  'CHECKUP1': 'Yes',
#  'BPHIGH4': 'No',
#  'BPMEDS': 'No',
#  'BLOODCHO': 'No',
#  'CHOLCHK': 'No',
#  'TOLDHI2': 'No',
#  'CVDSTRK3': 'Yes',
#  'ASTHMA3': 'No',
#  'ASTHNOW': 'No',
#  'CHCSCNCR': 'Yes',
#  'CHCOCNCR': 'Yes',
#  'CHCCOPD1': 'Yes',
#  'HAVARTH3': 'Yes',
#  'ADDEPEV2': 'Yes',
#  'CHCKIDNY': 'Yes',
#  'DIABETE3': 'Yes',
#  'DIABAGE2': 'No',
#  'SEX': 'Yes',
#  'MARITAL': 'No',
#  'EDUCA': 'Yes',
#  'RENTHOM1': 'No',
#  'NUMHHOL2': 'No',
#  'NUMPHON2': 'No',
#  'CPDEMO1': 'No',
#  'VETERAN3': 'No',
#  'EMPLOY1': 'No',
#  'CHILDREN': 'No',
#  'INCOME2': 'Yes',
#  'INTERNET': 'No',
#  'WEIGHT2': 'No',
#  'HEIGHT3': 'No',
#  'PREGNANT': 'No',
#  'QLACTLM2': 'No',
#  'USEEQUIP': 'Yes',
#  'BLIND': 'No',
#  'DECIDE': 'No',
#  'DIFFWALK': 'Yes',
#  'DIFFDRES': 'No',
#  'DIFFALON': 'No',
#  'SMOKE100': 'Yes',
#  'SMOKDAY2': 'No',
#  'STOPSMK2': 'No',
#  'LASTSMK2': 'No',
#  'USENOW3': 'No',
#  'ALCDAY5': 'No',
#  'AVEDRNK2': 'No',
#  'DRNK3GE5': 'No',
#  'MAXDRNKS': 'Yes',
#  'FRUITJU1': 'No',
#  'FRUIT1': 'No',
#  'FVBEANS': 'No',
#  'FVGREEN': 'No',
#  'FVORANG': 'No',
#  'VEGETAB1': 'No',
#  'EXERANY2': 'No',
#  'EXRACT11': 'No',
#  'EXEROFT1': 'No',
#  'EXERHMM1': 'No',
#  'EXRACT21': 'No',
#  'EXEROFT2': 'No',
#  'EXERHMM2': 'No',
#  'STRENGTH': 'No',
#  'LMTJOIN3': 'No',
#  'ARTHDIS2': 'No',
#  'ARTHSOCL': 'No',
#  'JOINPAIN': 'No',
#  'SEATBELT': 'No',
#  'FLUSHOT6': 'No',
#  'FLSHTMY2': 'No',
#  'IMFVPLAC': 'No',
#  'PNEUVAC3': 'No',
#  'HIVTST6': 'No',
#  'HIVTSTD3': 'No',
#  'WHRTST10': 'No',
#  'PDIABTST': 'No',
#  'PREDIAB1': 'No',
#  'INSULIN': 'No',
#  'BLDSUGAR': 'No',
#  'FEETCHK2': 'No',
#  'DOCTDIAB': 'No',
#  'CHKHEMO3': 'No',
#  'FEETCHK': 'No',
#  'EYEEXAM': 'No',
#  'DIABEYE': 'No',
#  'DIABEDU': 'No',
#  'CAREGIV1': 'No',
#  'CRGVREL1': 'No',
#  'CRGVLNG1': 'No',
#  'CRGVHRS1': 'No',
#  'CRGVPRB1': 'No',
#  'CRGVPERS': 'No',
#  'CRGVHOUS': 'No',
#  'CRGVMST2': 'No',
#  'CRGVEXPT': 'No',
#  'VIDFCLT2': 'No',
#  'VIREDIF3': 'No',
#  'VIPRFVS2': 'No',
#  'VINOCRE2': 'No',
#  'VIEYEXM2': 'No',
#  'VIINSUR2': 'No',
#  'VICTRCT4': 'No',
#  'VIGLUMA2': 'No',
#  'VIMACDG2': 'No',
#  'CIMEMLOS': 'No',
#  'CDHOUSE': 'No',
#  'CDASSIST': 'No',
#  'CDHELP': 'No',
#  'CDSOCIAL': 'No',
#  'CDDISCUS': 'No',
#  'WTCHSALT': 'No',
#  'LONGWTCH': 'No',
#  'DRADVISE': 'No',
#  'ASTHMAGE': 'No',
#  'ASATTACK': 'No',
#  'ASERVIST': 'No',
#  'ASDRVIST': 'No',
#  'ASRCHKUP': 'No',
#  'ASACTLIM': 'No',
#  'ASYMPTOM': 'No',
#  'ASNOSLEP': 'No',
#  'ASTHMED3': 'No',
#  'ASINHALR': 'No',
#  'HAREHAB1': 'No',
#  'STREHAB1': 'No',
#  'CVDASPRN': 'No',
#  'ASPUNSAF': 'No',
#  'RLIVPAIN': 'No',
#  'RDUCHART': 'No',
#  'RDUCSTRK': 'No',
#  'ARTTODAY': 'No',
#  'ARTHWGT': 'No',
#  'ARTHEXER': 'No',
#  'ARTHEDU': 'No',
#  'TETANUS': 'No',
#  'HPVADVC2': 'No',
#  'HPVADSHT': 'No',
#  'SHINGLE2': 'No',
#  'HADMAM': 'No',
#  'HOWLONG': 'No',
#  'HADPAP2': 'No',
#  'LASTPAP2': 'No',
#  'HPVTEST': 'No',
#  'HPLSTTST': 'No',
#  'HADHYST2': 'No',
#  'PROFEXAM': 'No',
#  'LENGEXAM': 'No',
#  'BLDSTOOL': 'No',
#  'LSTBLDS3': 'No',
#  'HADSIGM3': 'No',
#  'HADSGCO1': 'No',
#  'LASTSIG3': 'No',
#  'PCPSAAD2': 'No',
#  'PCPSADI1': 'No',
#  'PCPSARE1': 'No',
#  'PSATEST1': 'No',
#  'PSATIME': 'No',
#  'PCPSARS1': 'No',
#  'PCPSADE1': 'No',
#  'PCDMDECN': 'No',
#  'SCNTMNY1': 'No',
#  'SCNTMEL1': 'No',
#  'SCNTPAID': 'No',
#  'SCNTWRK1': 'No',
#  'SCNTLPAD': 'No',
#  'SCNTLWK1': 'No',
#  'SXORIENT': 'No',
#  'TRNSGNDR': 'No',
#  'RCSGENDR': 'No',
#  'RCSRLTN2': 'No',
#  'CASTHDX2': 'No',
#  'CASTHNO2': 'No',
#  'EMTSUPRT': 'No',
#  'LSATISFY': 'No',
#  'ADPLEASR': 'No',
#  'ADDOWN': 'No',
#  'ADSLEEP': 'No',
#  'ADENERGY': 'No',
#  'ADEAT1': 'No',
#  'ADFAIL': 'No',
#  'ADTHINK': 'No',
#  'ADMOVE': 'No',
#  'MISTMNT': 'No',
#  'ADANXEV': 'No',
#  'QSTVER': 'No',
#  'QSTLANG': 'No',
#  'MSCODE': 'No',
#  '_STSTR': 'No',
#  '_STRWT': 'No',
#  '_RAWRAKE': 'No',
#  '_WT2RAKE': 'No',
#  '_CHISPNC': 'No',
#  '_CRACE1': 'No',
#  '_CPRACE': 'No',
#  '_CLLCPWT': 'No',
#  '_DUALUSE': 'No',
#  '_DUALCOR': 'No',
#  '_LLCPWT': 'No',
#  '_RFHLTH': 'No',
#  '_HCVU651': 'No',
#  '_RFHYPE5': 'Yes',
#  '_CHOLCHK': 'No',
#  '_RFCHOL': 'Yes',
#  '_LTASTH1': 'No',
#  '_CASTHM1': 'No',
#  '_ASTHMS1': 'Yes',
#  '_DRDXAR1': 'Yes',
#  '_PRACE1': 'No',
#  '_MRACE1': 'No',
#  '_HISPANC': 'No',
#  '_RACE': 'Yes',
#  '_RACEG21': 'No',
#  '_RACEGR3': 'No',
#  '_RACE_G1': 'No',
#  '_AGEG5YR': 'Yes',
#  '_AGE65YR': 'No',
#  '_AGE80': 'No',
#  '_AGE_G': 'No',
#  'HTIN4': 'No',
#  'HTM4': 'No',
#  'WTKG3': 'No',
#  '_BMI5': 'Yes',
#  '_BMI5CAT': 'No',
#  '_RFBMI5': 'No',
#  '_CHLDCNT': 'No',
#  '_EDUCAG': 'No',
#  '_INCOMG': 'No',
#  '_SMOKER3': 'Yes',
#  '_RFSMOK3': 'No',
#  'DRNKANY5': 'No',
#  'DROCDY3_': 'Yes',
#  '_RFBING5': 'No',
#  '_DRNKWEK': 'Yes',
#  '_RFDRHV5': 'No',
#  'FTJUDA1_': 'No',
#  'FRUTDA1_': 'No',
#  'BEANDAY_': 'No',
#  'GRENDAY_': 'No',
#  'ORNGDAY_': 'No',
#  'VEGEDA1_': 'No',
#  '_MISFRTN': 'No',
#  '_MISVEGN': 'No',
#  '_FRTRESP': 'No',
#  '_VEGRESP': 'No',
#  '_FRUTSUM': 'No',
#  '_VEGESUM': 'No',
#  '_FRTLT1': 'Yes',
#  '_VEGLT1': 'Yes',
#  '_FRT16': 'No',
#  '_VEG23': 'No',
#  '_FRUITEX': 'No',
#  '_VEGETEX': 'No',
#  '_TOTINDA': 'Yes',
#  'METVL11_': 'Yes',
#  'METVL21_': 'No',
#  'MAXVO2_': 'Yes',
#  'FC60_': 'Yes',
#  'ACTIN11_': 'No',
#  'ACTIN21_': 'No',
#  'PADUR1_': 'No',
#  'PADUR2_': 'No',
#  'PAFREQ1_': 'No',
#  'PAFREQ2_': 'No',
#  '_MINAC11': 'No',
#  '_MINAC21': 'No',
#  'STRFREQ_': 'Yes',
#  'PAMISS1_': 'No',
#  'PAMIN11_': 'No',
#  'PAMIN21_': 'No',
#  'PA1MIN_': 'No',
#  'PAVIG11_': 'No',
#  'PAVIG21_': 'No',
#  'PA1VIGM_': 'No',
#  '_PACAT1': 'No',
#  '_PAINDX1': 'No',
#  '_PA150R2': 'No',
#  '_PA300R2': 'No',
#  '_PA30021': 'No',
#  '_PASTRNG': 'No',
#  '_PAREC1': 'No',
#  '_PASTAE1': 'No',
#  '_LMTACT1': 'No',
#  '_LMTWRK1': 'No',
#  '_LMTSCL1': 'No',
#  '_RFSEAT2': 'No',
#  '_RFSEAT3': 'No',
#  '_FLSHOT6': 'No',
#  '_PNEUMO2': 'No',
#  '_AIDTST3': 'No'}

# %%
useful_col_array = [col_name for col_name, value in useful_col.items() if value == 'Yes']
(df_X[useful_col_array].GENHLTH == 7).value_counts()
# Out:
# False    327573
# True        562
# Name: GENHLTH, dtype: int64

# %%
indices_to_keep = [index for index, (_, value) in enumerate(useful_col.items()) if value == 'Yes']
print(len(indices_to_keep))
print(indices_to_keep)
for i, x in enumerate(indices_to_keep):
    indices_to_keep[i] = x-1 
print(indices_to_keep, end=",")
# Out:
# 37

# %%
X= [[value for i, value in enumerate(arr) if i in indices_to_keep] for arr in x_train]
