# %%
import pandas as pd
df_X = pd.read_csv("../data/raw/x_train.csv")

# %%
df_X
# Out:
#         _STATE  FMONTH     IDATE  IMONTH  IDAY  IYEAR  DISPCODE       SEQNO  \
# 0           53      11  11162015      11    16   2015      1100  2015015629
# 1           33      12  12152015      12    15   2015      1200  2015004387
# 2           20      10  10202015      10    20   2015      1100  2015005638
# 3           42       6   6182015       6    18   2015      1100  2015004694
# 4           24      11  11062015      11     6   2015      1100  2015004673
# ...        ...     ...       ...     ...   ...    ...       ...         ...
# 328130      49       7  11232015      11    23   2015      1100  2015006796
# 328131      51       5   6082015       6     8   2015      1100  2015006482
# 328132      39      10  10202015      10    20   2015      1100  2015004898
# 328133      33      12  12302015      12    30   2015      1100  2015004449
# 328134      32       9   9122015       9    12   2015      1100  2015001176
#
# ...

# %%
useful_col = dict.fromkeys(df_X.columns, 'No')

# %%
useful_col
# Out:
# {'_STATE': 'No',
#  'FMONTH': 'No',
#  'IDATE': 'No',
#  'IMONTH': 'No',
#  'IDAY': 'No',
#  'IYEAR': 'No',
#  'DISPCODE': 'No',
#  'SEQNO': 'No',
#  '_PSU': 'No',
#  'CTELENUM': 'No',
#  'PVTRESD1': 'No',
#  'COLGHOUS': 'No',
#  'STATERES': 'No',
#  'CELLFON3': 'No',
#  'LADULT': 'No',
#  'NUMADULT': 'No',
#  'NUMMEN': 'No',
#  'NUMWOMEN': 'No',
#  'CTELNUM1': 'No',
#  'CELLFON2': 'No',
#  'CADULT': 'No',
#  'PVTRESD2': 'No',
#  'CCLGHOUS': 'No',
#  'CSTATE': 'No',
#  'LANDLINE': 'No',
#  'HHADULT': 'No',
#  'GENHLTH': 'Yes',
#  'PHYSHLTH': 'No',
#  'MENTHLTH': 'Yes',
#  'POORHLTH': 'No',
#  'HLTHPLN1': 'Yes',
#  'PERSDOC2': 'No',
#  'MEDCOST': 'Yes',
#  'CHECKUP1': 'Yes',
#  'BPHIGH4': 'No',
#  'BPMEDS': 'No',
#  'BLOODCHO': 'No',
#  'CHOLCHK': 'No',
#  'TOLDHI2': 'No',
#  'CVDSTRK3': 'Yes',
#  'ASTHMA3': 'No',
#  'ASTHNOW': 'No',
#  'CHCSCNCR': 'Yes',
#  'CHCOCNCR': 'Yes',
#  'CHCCOPD1': 'Yes',
#  'HAVARTH3': 'No',
#  'ADDEPEV2': 'Yes',
#  'CHCKIDNY': 'No',
#  'DIABETE3': 'Yes',
# ...

# %%
# useful columns:
useful_col['GENHLTH'] = 'Yes' #same as ex
useful_col['MENTHLTH'] = 'Yes' #same as ex
useful_col['PHYSHLTH'] = 'Yes' #same as ex
useful_col['HLTHPLN1'] = 'Yes' #same as ex
useful_col['MEDCOST'] = 'Yes' #same as ex
useful_col['CHECKUP1'] = 'Yes'
useful_col['CVDSTRK3'] = 'Yes' #same as ex
useful_col['CHCSCNCR'] = 'Yes'
useful_col['CHCOCNCR'] = 'Yes'
useful_col['CHCCOPD1'] = 'Yes'
useful_col['ADDEPEV2'] = 'Yes'
useful_col['DIABETE3'] = 'Yes' #same as ex
useful_col['SEX'] = 'Yes'
useful_col['MAXDRNKS'] = 'Yes'
useful_col['EXEROFT1'] = 'Yes'
useful_col['_RFHLTH'] = 'Yes'
useful_col['_HCVU651'] = 'Yes'
useful_col['_RFHYPE5'] = 'Yes' #same as ex
useful_col['_RFCHOL'] = 'Yes'
useful_col['_ASTHMS1'] = 'Yes'
useful_col['_DRDXAR1'] = 'Yes'
useful_col['_RACE'] = 'Yes'
useful_col['_BMI5'] = 'Yes' #same as ex
useful_col['_AGEG5YR'] = 'Yes'
useful_col['_SMOKER3'] = 'Yes'
useful_col['_DRNKWEK'] = 'Yes'
useful_col['_FRTLT1'] = 'Yes' #same as ex
useful_col['_VEGLT1'] = 'Yes' #same as ex
useful_col['_TOTINDA'] = 'Yes' #same as ex
useful_col['FC60_'] = 'Yes'
useful_col['PA1MIN_'] = 'Yes'
