# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import pandas as pd
import csv
import sys 

# %load_ext autoreload
# %autoreload 2

sys.path.append("../")
from src import helpers, preprocessing, exploration, polynomial_exp
from src.helpers import split_data_rand
from src.helpers import build_model_data
from sklearn.metrics import f1_score
from src.json_parser import parse_json_file
from sklearn.linear_model import LogisticRegression
from src.preprocessing import clean_data
from src.preprocessing import undefined_to_median, undefined_to_mean, prune_undefined
from imblearn.combine import SMOTEENN
pd.set_option("display.max_column", 100)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
x_train = pd.read_csv("../data/raw/x_train.csv")
x_train
# Out:
#             Id  _STATE  FMONTH     IDATE  IMONTH  IDAY  IYEAR  DISPCODE  \
# 0            0      53      11  11162015      11    16   2015      1100
# 1            1      33      12  12152015      12    15   2015      1200
# 2            2      20      10  10202015      10    20   2015      1100
# 3            3      42       6   6182015       6    18   2015      1100
# 4            4      24      11  11062015      11     6   2015      1100
# ...        ...     ...     ...       ...     ...   ...    ...       ...
# 328130  328130      49       7  11232015      11    23   2015      1100
# 328131  328131      51       5   6082015       6     8   2015      1100
# 328132  328132      39      10  10202015      10    20   2015      1100
# 328133  328133      33      12  12302015      12    30   2015      1100
# 328134  328134      32       9   9122015       9    12   2015      1100
#
#              SEQNO        _PSU  CTELENUM  PVTRESD1  COLGHOUS  STATERES  \
# 0       2015015629  2015015629       NaN       NaN       NaN       NaN
# 1       2015004387  2015004387       1.0       1.0       NaN       1.0
# 2       2015005638  2015005638       1.0       1.0       NaN       1.0
# 3       2015004694  2015004694       NaN       NaN       NaN       NaN
# 4       2015004673  2015004673       1.0       1.0       NaN       1.0
# ...            ...         ...       ...       ...       ...       ...
# 328130  2015006796  2015006796       NaN       NaN       NaN       NaN
# 328131  2015006482  2015006482       NaN       NaN       NaN       NaN
# 328132  2015004898  2015004898       1.0       1.0       NaN       1.0
# 328133  2015004449  2015004449       1.0       1.0       NaN       1.0
# 328134  2015001176  2015001176       1.0       1.0       NaN       1.0
#
#         CELLFON3  LADULT  NUMADULT  NUMMEN  NUMWOMEN  CTELNUM1  CELLFON2  \
# 0            NaN     NaN       NaN     NaN       NaN       1.0       1.0
# 1            1.0     NaN       2.0     1.0       1.0       NaN       NaN
# 2            2.0     NaN       2.0     1.0       1.0       NaN       NaN
# 3            NaN     NaN       NaN     NaN       NaN       1.0       1.0
# 4            1.0     NaN       1.0     1.0       0.0       NaN       NaN
# ...          ...     ...       ...     ...       ...       ...       ...
# 328130       NaN     NaN       NaN     NaN       NaN       1.0       1.0
# 328131       NaN     NaN       NaN     NaN       NaN       1.0       1.0
# 328132       1.0     NaN       1.0     0.0       1.0       NaN       NaN
# 328133       1.0     NaN       3.0     2.0       1.0       NaN       NaN
# 328134       2.0     NaN       2.0     1.0       1.0       NaN       NaN
#
#         CADULT  PVTRESD2  CCLGHOUS  CSTATE  LANDLINE  HHADULT  GENHLTH  \
# 0          2.0       1.0       NaN     1.0       1.0      2.0      2.0
# 1          NaN       NaN       NaN     NaN       NaN      NaN      4.0
# 2          NaN       NaN       NaN     NaN       NaN      NaN      2.0
# 3          2.0       1.0       NaN     1.0       2.0      2.0      1.0
# 4          NaN       NaN       NaN     NaN       NaN      NaN      2.0
# ...        ...       ...       ...     ...       ...      ...      ...
# 328130     1.0       1.0       NaN     1.0       2.0      2.0      2.0
# 328131     1.0       1.0       NaN     1.0       2.0      2.0      1.0
# 328132     NaN       NaN       NaN     NaN       NaN      NaN      3.0
# 328133     NaN       NaN       NaN     NaN       NaN      NaN      3.0
# 328134     NaN       NaN       NaN     NaN       NaN      NaN      2.0
#
#         PHYSHLTH  MENTHLTH  POORHLTH  HLTHPLN1  PERSDOC2  MEDCOST  CHECKUP1  \
# 0            1.0         5      88.0         1         1      2.0       1.0
# 1           88.0        88       NaN         1         1      2.0       1.0
# 2           77.0        77      88.0         1         1      2.0       1.0
# 3           88.0        88       NaN         1         1      2.0       1.0
# 4           88.0        88       NaN         1         9      2.0       1.0
# ...          ...       ...       ...       ...       ...      ...       ...
# 328130      88.0        88       NaN         1         1      2.0       1.0
# 328131      88.0        88       NaN         1         1      2.0       1.0
# 328132      88.0         1      88.0         1         1      2.0       1.0
# 328133      88.0        88       NaN         1         1      2.0       1.0
# 328134       7.0         7       2.0         1         2      1.0       1.0
#
#         BPHIGH4  BPMEDS  BLOODCHO  CHOLCHK  TOLDHI2  CVDSTRK3  ASTHMA3  \
# 0           3.0     NaN         1      1.0      2.0         2        2
# 1           1.0     1.0         1      1.0      2.0         2        2
# 2           3.0     NaN         1      1.0      1.0         2        2
# 3           3.0     NaN         1      4.0      2.0         2        2
# 4           3.0     NaN         1      3.0      2.0         2        2
# ...         ...     ...       ...      ...      ...       ...      ...
# 328130      1.0     1.0         1      1.0      2.0         2        2
# 328131      3.0     NaN         1      7.0      2.0         2        2
# 328132      3.0     NaN         1      1.0      1.0         2        2
# 328133      3.0     NaN         1      1.0      2.0         2        1
# 328134      1.0     2.0         1      1.0      2.0         2        2
#
#         ASTHNOW  CHCSCNCR  CHCOCNCR  CHCCOPD1  HAVARTH3  ADDEPEV2  CHCKIDNY  \
# 0           NaN       2.0         2         2       2.0         1         2
# 1           NaN       2.0         2         2       2.0         2         2
# 2           NaN       2.0         2         2       1.0         2         2
# 3           NaN       2.0         2         2       1.0         2         2
# 4           NaN       2.0         2         2       2.0         2         2
# ...         ...       ...       ...       ...       ...       ...       ...
# 328130      NaN       1.0         1         2       2.0         2         2
# 328131      NaN       2.0         2         2       2.0         2         2
# 328132      NaN       2.0         2         2       2.0         1         2
# 328133      1.0       2.0         2         2       2.0         2         2
# 328134      NaN       2.0         2         2       1.0         2         2
#
#         DIABETE3  ...  VEGEDA1_  _MISFRTN  _MISVEGN  _FRTRESP  _VEGRESP  \
# 0            3.0  ...      0.71         0         0         1         1
# 1            3.0  ...       NaN         2         4         0         0
# 2            3.0  ...      1.00         0         0         1         1
# 3            3.0  ...      1.00         0         0         1         1
# 4            3.0  ...      0.83         0         0         1         1
# ...          ...  ...       ...       ...       ...       ...       ...
# 328130       3.0  ...      1.00         0         0         1         1
# 328131       3.0  ...      0.20         0         0         1         1
# 328132       3.0  ...      0.57         0         0         1         1
# 328133       3.0  ...      0.13         0         0         1         1
# 328134       3.0  ...      2.00         0         0         1         1
#
#         _FRUTSUM  _VEGESUM  _FRTLT1  _VEGLT1  _FRT16  _VEG23  _FRUITEX  \
# 0           0.71      1.21        2        1       1       1         0
# 1            NaN       NaN        9        9       1       1         1
# 2           2.03      2.86        1        1       1       1         0
# 3           0.00      2.78        2        1       1       1         0
# 4           1.50      1.73        1        1       1       1         0
# ...          ...       ...      ...      ...     ...     ...       ...
# 328130      1.00      1.89        1        1       1       1         0
# 328131      1.00      2.34        1        1       1       1         0
# 328132      1.00      0.78        1        2       1       1         0
# 328133      0.07      0.36        2        2       1       1         0
# 328134      4.00      7.00        1        1       1       1         0
#
#         _VEGETEX  _TOTINDA  METVL11_  METVL21_  MAXVO2_   FC60_  ACTIN11_  \
# 0              0         1       3.5       4.5    26.91    4.61       1.0
# 1              1         9       NaN       NaN    28.65    4.91       NaN
# 2              0         1       3.5       0.0    23.95    4.11       1.0
# 3              0         1       4.5       5.5    23.95    4.11       2.0
# 4              0         1       3.5       4.0   999.00  999.00       NaN
# ...          ...       ...       ...       ...      ...     ...       ...
# 328130         0         1       3.5       4.0    28.65    4.91       1.0
# 328131         0         1       6.8       6.0    29.75    5.10       2.0
# 328132         0         1       3.5       0.0    22.84    3.92       1.0
# 328133         0         1       7.3       0.0    36.35    6.23       2.0
# 328134         0         1       3.5       0.0    29.13    4.99       1.0
#
#         ACTIN21_  PADUR1_  PADUR2_  PAFREQ1_  PAFREQ2_  _MINAC11  _MINAC21  \
# 0            1.0     30.0     30.0     2.000     4.667      60.0     140.0
# 1            NaN      NaN      NaN       NaN       NaN       NaN       NaN
# 2            0.0     30.0      NaN     3.000       NaN      90.0       0.0
# 3            2.0    120.0    180.0     5.000     1.000     600.0     180.0
# 4            NaN     60.0     60.0     4.667       NaN     280.0       NaN
# ...          ...      ...      ...       ...       ...       ...       ...
# 328130       1.0     25.0    120.0     3.000     1.000      75.0     120.0
# 328131       2.0     90.0     45.0     5.000     0.467     450.0      21.0
# 328132       0.0     30.0      NaN     4.000       NaN     120.0       0.0
# 328133       0.0     30.0      NaN     0.467       NaN      14.0       0.0
# 328134       0.0      NaN     60.0     4.000     3.000       NaN       0.0
#
#         STRFREQ_  PAMISS1_  PAMIN11_  PAMIN21_  PA1MIN_  PAVIG11_  PAVIG21_  \
# 0          5.000         0      60.0     140.0    200.0       0.0       0.0
# 1            NaN         9       NaN       NaN      NaN       NaN       NaN
# 2          0.000         0      90.0       0.0     90.0       0.0       0.0
# 3          0.233         0    1200.0     360.0   1560.0     600.0     180.0
# 4          0.000         1       NaN       NaN      NaN       NaN       NaN
# ...          ...       ...       ...       ...      ...       ...       ...
# 328130     0.000         0      75.0     120.0    195.0       0.0       0.0
# 328131     3.000         0     900.0      42.0    942.0     450.0      21.0
# 328132     4.000         0     120.0       0.0    120.0       0.0       0.0
# 328133     3.000         0      28.0       0.0     28.0      14.0       0.0
# 328134     2.000         1       NaN       0.0      0.0       0.0       0.0
#
#         PA1VIGM_  _PACAT1  _PAINDX1  _PA150R2  _PA300R2  _PA30021  _PASTRNG  \
# 0            0.0        2         1         1         2         2         1
# 1            NaN        9         9         9         9         9         9
# 2            0.0        3         2         2         2         2         2
# 3          780.0        1         1         1         1         1         2
# 4            NaN        9         9         9         9         9         2
# ...          ...      ...       ...       ...       ...       ...       ...
# 328130       0.0        2         1         1         2         2         2
# 328131     471.0        1         1         1         1         1         1
# 328132       0.0        3         2         2         2         2         1
# 328133      14.0        3         2         2         2         2         1
# 328134       0.0        9         9         9         9         9         1
#
#         _PAREC1  _PASTAE1  _LMTACT1  _LMTWRK1  _LMTSCL1  _RFSEAT2  _RFSEAT3  \
# 0             1         1       3.0       3.0       4.0         1         1
# 1             9         9       3.0       3.0       4.0         9         9
# 2             4         2       2.0       2.0       3.0         1         1
# 3             2         2       2.0       2.0       3.0         1         1
# 4             9         9       3.0       3.0       4.0         1         1
# ...         ...       ...       ...       ...       ...       ...       ...
# 328130        2         2       3.0       3.0       4.0         1         1
# 328131        1         1       3.0       3.0       4.0         1         1
# 328132        3         2       3.0       3.0       4.0         1         2
# 328133        3         2       3.0       3.0       4.0         1         1
# 328134        9         9       2.0       2.0       3.0         1         1
#
#         _FLSHOT6  _PNEUMO2  _AIDTST3
# 0            NaN       NaN       2.0
# 1            NaN       NaN       NaN
# 2            1.0       2.0       2.0
# 3            2.0       2.0       2.0
# 4            9.0       9.0       2.0
# ...          ...       ...       ...
# 328130       NaN       NaN       2.0
# 328131       NaN       NaN       1.0
# 328132       2.0       2.0       2.0
# 328133       NaN       NaN       2.0
# 328134       NaN       NaN       2.0
#
# [328135 rows x 322 columns]

# %%
x_train = x_train.values
features = parse_json_file("features.json")

# %%
x_train = clean_data(features, x_train)
x_train
# Out:
# [7, 9] {2: 0}
# [77, 99] {88: 0}
# array([[0.        , 1.        ],
#        [4.        , 0.        ],
#        [0.        , 4.26744479],
#        ...,
#        [3.        , 0.        ],
#        [3.        , 0.        ],
#        [0.        , 7.        ]])
